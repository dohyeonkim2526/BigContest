# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyeonkim2526/BigContest/blob/master/rating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import pandas as pd

dir='/content/gdrive/My Drive/빅데이터 공모전/빅콘테스트 데이터/문제데이터_update_0818/제공데이터'
data ='시청률 데이터.xlsx'
rate_dir=os.path.join(dir, data)

# %%
rating=pd.read_excel(rate_dir,header=1)

# %%
rating[:10]
# Out:
#      시간대  2019-01-01  ...  2019-12-31  2019-01-01 to 2019-12-31
# 0  02:00       0.000  ...       0.000                     0.003
# 1  02:01       0.000  ...       0.012                     0.003
# 2  02:02       0.000  ...       0.000                     0.004
# 3  02:03       0.000  ...       0.000                     0.004
# 4  02:04       0.000  ...       0.000                     0.004
# 5  02:05       0.000  ...       0.000                     0.004
# 6  02:06       0.000  ...       0.000                     0.003
# 7  02:07       0.000  ...       0.000                     0.003
# 8  02:08       0.000  ...       0.000                     0.003
# 9  02:09       0.014  ...       0.000                     0.003
#
# [10 rows x 367 columns]

# %%
df_lst = []
for i in col_names:
  df_lst.append(rating[i])

new_df = pd.concat(df_lst, ignore_index=True)

# %%
final_df = pd.concat([new_idx, new_df], axis=1)
final_df.columns = ['date','rate']

# %%
final_df['date'] = pd.to_datetime(final_df['date'])

# %%
final_df['방송시간']=final_df['date'].dt.time
final_df['date']=final_df['date'].dt.date

# %%
final_df.rename(columns={"date":"방송날짜"},inplace=True)

# %%
final_df=final_df[['방송날짜','방송시간','rate']]

# %%
final_df
# Out:
#               방송날짜      방송시간  rate
# 0       2019-01-01  02:00:00   0.0
# 1       2019-01-01  02:01:00   0.0
# 2       2019-01-01  02:02:00   0.0
# 3       2019-01-01  02:03:00   0.0
# 4       2019-01-01  02:04:00   0.0
# ...            ...       ...   ...
# 525595  2019-12-31  01:55:00   0.0
# 525596  2019-12-31  01:56:00   0.0
# 525597  2019-12-31  01:57:00   0.0
# 525598  2019-12-31  01:58:00   0.0
# 525599  2019-12-31  01:59:00   0.0
#
# [525600 rows x 3 columns]

# %%
mk_dir='/content/gdrive/My Drive/빅데이터 공모전/빅콘테스트 데이터'
mk_name='rating.xlsx'
make_dir=os.path.join(mk_dir,mk_name)

# %%
final_df.to_excel(make_dir)
